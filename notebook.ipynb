# %% [markdown]
# <h3><b>Aqui</b> eu escrevo meu texto!!!<h3>
#
# # Aqui escrevo meu título nível 1.
#
# ## Aqui **escrevo** meu subtítulo!
# ---
# *Itálico*<br />
# **Negrito**<br />
# ***Negrito itálico***<br />
#
# Este é um texto normal.
#
# Exemplo no código no *hello world* no *Markdown*:<br />
# `print('Hello World')`
# <br /><br />
# 1. Você vai clicar em **Não**?<br /><br />
# <input type="radio" name="questão"><span>Sim<br />
# <input type="radio" name="questão"><span>Não<br />
# <br />
# 2. Informe suas habilidades:<br />
# <input type="checkbox" name="hab"> Operador de Micro<br />
# <input type="checkbox" name="hab"> Operador de HTML<br />
# <input type="checkbox" name="hab"> Operador de Java<br />
# <input type="checkbox" name="hab"> Operador de Python<br />
#
# ### Tópicos:
# - Tópico 1
# - Tópico 2
# - Tópico 2
#
# ### Numeração
# 1. Numeração 1
# 2. Numeração 2
# 3. Numeração 3

# %% [markdown]
# ## Trabalhando com códigos em Jupyter:
# ---
#
# Abaixo segue um exemplo de um código funcional em *Python* rodando em um *notebook*:

# %%
n1 = 15
n2 = 5
n3 = n1+n2
print(f'Qual o nome do filme?\n Resposta = O código da {n3}!')
# Out:
# Qual o nome do filme?
#  Resposta = O código da 20!

# %% [markdown]
# Repare que o código-fonte das células consideram o resultado das células anteriores do mesmo notebook.<br /> Observe no código a seguir:

# %%
x = 10
print(f'Resultado = {x*n3}')

# %% [markdown]
# Vamos ver como um código de entrada de dados se comporta em um notebook:

# %%
texto = input('Digite o texto aqui: ')
print(texto)
# Out:
# bruno

# %% [markdown]
# Imagem no Markdown:

# %% [markdown]
# ![image.png](attachment:image.png)
#
# é só da o ctrl+v
#
# ![image-2.png](attachment:image-2.png)
